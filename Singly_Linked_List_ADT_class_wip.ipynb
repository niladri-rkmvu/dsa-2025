# %% [markdown]
# <a href="https://colab.research.google.com/github/niladri-rkmvu/dsa-2025/blob/6.linked_list/Singly_Linked_List_ADT_class_wip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None

# %%
class LinkedList:
    def __init__(self,value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1

    def append(self,value):
        new_node = Node(value)

        if self.length == 0:
            self.head = new_node
        else:
            self.tail.next = new_node

        self.tail = new_node
        self.length += 1
        return True

    def print_list(self, msg = "Linked List Created"):
        print("---------")
        print(msg)
        print("---------")

        # added the logic of [if self.length == 0:]
        if self.length == 0:
            print("Linked List is empty")
            print("head = None")
            print("tail = None")
            print(f"length = {self.length}")
            return

        temp = self.head
        while(temp is not None):
            print(temp.value, end = " -> ")
            temp = temp.next
        print("None")
        print(" ")
        print(f"head = {self.head.value}")
        print(f"tail = {self.tail.value}")
        print(f"length = {self.length}")

    def pop(self):
        if self.length == 0:
            return None

        temp = self.head
        pre = self.head

        while(temp.next is not None):
            pre = temp
            temp = temp.next

        self.tail = pre
        pre.next = None
        self.length -= 1

        if self.length == 0:
            self.head = None
            self.tail = None

        return temp

    def prepend(self,value):
        new_node = Node(value)
        if self.length == 0:
            self.head = new_node # made the change here (cleaner version)
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node # made the change here (cleaner version)
        self.length += 1
        return True

# %%
my_linked_list = LinkedList(11)
my_linked_list.append(3)
my_linked_list.append(23)
my_linked_list.append(7)
my_linked_list.print_list()

popped_node = my_linked_list.pop()
my_linked_list.print_list("my_linked_list.pop()")
print(f"Popped node = {popped_node.value}")

my_linked_list.prepend(4)
my_linked_list.print_list("my_linked_list.prepend(4)")
# Out:
# ---------
# Linked List Created
# ---------
# 11 -> 3 -> 23 -> 7 -> None
#
# head = 11
# tail = 7
# length = 4
# ---------
# my_linked_list.pop()
# ---------
# 11 -> 3 -> 23 -> None
#
# head = 11
# tail = 23
# length = 3
# Popped node = 7
# ---------
# my_linked_list.prepend(4)
# ---------
# 4 -> 11 -> 3 -> 23 -> None
#
# head = 4
# tail = 23
# length = 4
