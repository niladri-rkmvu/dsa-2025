# %% [markdown]
# <a href="https://colab.research.google.com/github/niladri-rkmvu/dsa-2025/blob/1.a.Introduction/python_bytecode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def concatenator (a,b):
    return a + b

# %%
concatenator("Hello ","world")
# Out:
# 'Hello world'

# %%
concatenator("1 ","5")
# Out:
# '1 5'

# %%
concatenator
# Out:
# <function __main__.concatenator(a, b)>

# %%
concatenator.__code__
# Out:
# <code object concatenator at 0x7a951de981d0, file "/tmp/ipython-input-1-3448801352.py", line 1>

# %%
concatenator.__code__.co_argcount
# Out:
# 2

# %%
concatenator.__code__.co_filename
# Out:
# '/tmp/ipython-input-1-3448801352.py'

# %%
concatenator.__code__.co_code
# Out:
# b'\x97\x00|\x00|\x01z\x00\x00\x00S\x00'

# %%
import dis

# %%
dis.dis(concatenator)
# Out:
#   1           0 RESUME                   0
#
#   2           2 LOAD_FAST                0 (a)
#               4 LOAD_FAST                1 (b)
#               6 BINARY_OP                0 (+)
#              10 RETURN_VALUE
